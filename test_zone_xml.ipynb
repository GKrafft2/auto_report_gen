# %%
import xml.etree.ElementTree as ET
import os
import json
import re

# %load_ext autoreload
# %autoreload 2

# %%
test_xml_path = "C:/Users/eliot/Desktop/rapport automation/Rapport tempate/Stories/Story_u1a72.xml"
stories_folder = "C:/Users/eliot/Desktop/rapport automation/Rapport tempate/Stories/"
spreads_folder = "C:/Users/eliot/Desktop/rapport automation/Rapport tempate/Spreads/"

# %%
TEMPLATE_TOKENS = {
    "MAIN TITLE",
    "MAIN YEAR",
    "CONTENTS",
    "MESSAGE FROM THE PRESIDENT",
    "WHO WE ARE",
    "FIGURES",
    "PROJECTS SUPPORTED INTRO",
    "MAIN ARTICLE 1",
    "MAIN ARTICLE 2",
    "MAIN ARTICLE 3",
    "MAIN ARTICLE 4",
    "MAIN ARTICLE LR 1",
    "OTHER PROJECTS SUPPORTED",
    "OTHER PROJECT 1",
    "OTHER PROJECT 2",
    "OTHER PROJECT 3",
    "OTHER PROJECT 4",
    "COMPLETED PROJECTS",
    "COMPLETED PROJECT 1",
    "COMPLETED PROJECT 2",
    "COMPLTED PROJECT 3",
    "OUTLOOK",
}

# %%
# find which story contains the token
# find which spread contains the story

from template_preprocessing import create_json_ressources

create_json_ressources(stories_folder, spreads_folder)
